# %%
import pathlib
NOTEBOOK_PATH = pathlib.Path().resolve()
DATA_DIRECTORY = NOTEBOOK_PATH / "static" / "data"

# %%
import pandas
addresses = pandas.read_csv(
    DATA_DIRECTORY / "helsinki_addresses" / "addresses.txt",
    sep=";"
)

addresses.head()
# Out:
#      id                                           addr
# 0  1000       Itämerenkatu 14, 00101 Helsinki, Finland
# 1  1001          Kampinkuja 1, 00100 Helsinki, Finland
# 2  1002           Kaivokatu 8, 00101 Helsinki, Finland
# 3  1003  Hermannin rantatie 1, 00580 Helsinki, Finland
# 4  1005     Tyynenmerenkatu 9, 00220 Helsinki, Finland

# %%
import geopandas

geocoded_addresses = geopandas.tools.geocode(
    addresses["addr"],
    provider="nominatim",
    user_agent="autogis2023",
    timeout=10
)
geocoded_addresses.head()
# Out:
#                     geometry  \
# 0  POINT (24.91556 60.16320)
# 1  POINT (24.93166 60.16905)
# 2  POINT (24.94179 60.16989)
# 3  POINT (24.97840 60.18934)
# 4  POINT (24.92169 60.15667)
#
#                                              address
# 0  Ruoholahti, 14, Itämerenkatu, Ruoholahti, Läns...
# 1  Kamppi, 1, Kampinkuja, Kamppi, Eteläinen suurp...
# 2  Kauppakeskus Citycenter, 8, Kaivokatu, Keskust...
# 3  Hermannin rantatie, Verkkosaari, Kalasatama, S...
# 4  9, Tyynenmerenkatu, Jätkäsaari, Länsisatama, E...

# %%
geocoded_addresses_with_id = geocoded_addresses.join(addresses)
geocoded_addresses_with_id
# Out:
#                      geometry  \
# 0   POINT (24.91556 60.16320)
# 1   POINT (24.93166 60.16905)
# 2   POINT (24.94179 60.16989)
# 3   POINT (24.97840 60.18934)
# 4   POINT (24.92169 60.15667)
# 5   POINT (25.08174 60.23522)
# 6   POINT (25.10333 60.21807)
# 7   POINT (25.03572 60.27509)
# 8   POINT (25.02904 60.26347)
# 9   POINT (24.87197 60.22244)
# 10  POINT (24.94269 60.17118)
# 11  POINT (24.88442 60.23074)
# 12  POINT (24.87855 60.24018)
# 13  POINT (24.94854 60.22196)
# 14  POINT (25.01295 60.25107)
# 15  POINT (24.89418 60.21722)
# 16  POINT (24.85357 60.24682)
# 17  POINT (24.96566 60.22982)
# 18  POINT (24.93435 60.19857)
# 19  POINT (24.86067 60.22404)
# 20  POINT (24.99362 60.24365)
# 21  POINT (25.02833 60.24242)
# 22  POINT (25.07842 60.20984)
# 23  POINT (25.13871 60.20715)
# 24  POINT (25.07638 60.22329)
# 25  POINT (25.10827 60.23812)
# 26  POINT (24.96114 60.18797)
# 27  POINT (25.02832 60.19442)
# 28  POINT (25.00681 60.18872)
# 29  POINT (24.94960 60.17926)
# 30  POINT (24.93307 60.16908)
# 31  POINT (24.93039 60.16641)
# 32  POINT (24.92121 60.15878)
# 33  POINT (24.94694 60.17198)
#
#                                               address    id  \
# 0   Ruoholahti, 14, Itämerenkatu, Ruoholahti, Läns...  1000
# 1   Kamppi, 1, Kampinkuja, Kamppi, Eteläinen suurp...  1001
# 2   Kauppakeskus Citycenter, 8, Kaivokatu, Keskust...  1002
# 3   Hermannin rantatie, Verkkosaari, Kalasatama, S...  1003
# 4   9, Tyynenmerenkatu, Jätkäsaari, Länsisatama, E...  1005
# 5   18, Kontulantie, Kontula, Mellunkylä, Itäinen ...  1006
# 6   Itäväylä, Vartioharju, Vartiokylä, Itäinen suu...  1007
# 7   Tapulikaupungintie, Tapulikaupunki, Suutarila,...  1008
# 8   Sompionpolku, Fallkullan kiila, Tapanila, Tapa...  1009
# 9   5, Atomitie, Strömberg, Pitäjänmäen teollisuus...  1010
# 10  Rautatientori, Keskusta, Kluuvi, Eteläinen suu...  1011
# 11  Kuparitie, Lassila, Haaga, Läntinen suurpiiri,...  1012
# 12  Rumpupolku, Kannelmäki, Kaarela, Läntinen suur...  1013
# 13  Otto. automaatti (ATM), 1, Mäkitorpantie, Pato...  1014
# 14  Yliopiston Apteekki, 15, Malminkaari, Ala-Malm...  1015
# 15  23, Kylätie, Etelä-Haaga, Haaga, Läntinen suur...  1016
# 16  Malminkartanontie, Malminkartano, Kaarela, Län...  1017
# 17  Oulunkylän tori, Patola, Oulunkylä, Pohjoinen ...  1018
# 18  6, Ratapihantie, Itä-Pasila, Pasila, Keskinen ...  1019
# 19  Rakennuskonsultointi Treuthardt Oy, 15, Pitäjä...  1020
# 20  K-Market, 2, Eskolantie, Savela, Pukinmäki, Ko...  1021
# 21  Tattariharjuntie, Sepänmäki, Ala-Malmi, Malmi,...  1022
# 22  Otto. pankkiautomaatti, 1, Tallinnanaukio, Itä...  1023
# 23  Tyynylaavantie, Keski-Vuosaari, Vuosaari, Itäi...  1024
# 24  Myllypurontie, Puu-Myllypuro, Myllypuro, Varti...  1025
# 25  Mellunmäenraitio, Mellunmäki, Mellunkylä, Itäi...  1026
# 26  Vaasanpolku, Kurvi, Harju, Alppiharju, Keskine...  1027
# 27  Alko, 2, Hiihtäjäntie, Länsi-Herttoniemi, Hert...  1028
# 28  Metro Kulosaari, 2, Ukko-Pekan porras, Kulosaa...  1029
# 29  16, Siltasaarenkatu, Siltasaari, Kallio, Keski...  1030
# 30  Kampin keskus, 1, Urho Kekkosen katu, Kamppi, ...  1031
# 31  Ruoholahdenkatu, Kamppi, Eteläinen suurpiiri, ...  1032
# 32  3, Tyynenmerenkatu, Jätkäsaari, Länsisatama, E...  1033
# 33  4, Vilhonkatu, Kaisaniemi, Kluuvi, Eteläinen s...  1034
#
#                                              addr
# 0        Itämerenkatu 14, 00101 Helsinki, Finland
# 1           Kampinkuja 1, 00100 Helsinki, Finland
# 2            Kaivokatu 8, 00101 Helsinki, Finland
# 3   Hermannin rantatie 1, 00580 Helsinki, Finland
# 4      Tyynenmerenkatu 9, 00220 Helsinki, Finland
# 5         Kontulantie 18, 00940 Helsinki, Finland
# 6             Itäväylä 3, 00950 Helsinki, Finland
# 7   Tapulikaupungintie 3, 00750 Helsinki, Finland
# 8         Sompionpolku 2, 00730 Helsinki, Finland
# 9             Atomitie 5, 00370 Helsinki, Finland
# 10       Rautatientori 1, 00100 Helsinki, Finland
# 11           Kuparitie 8, 00440 Helsinki, Finland
# 12          Rumpupolku 8, 00420 Helsinki, Finland
# 13       Mäkitorpantie 1, 00620 Helsinki, Finland
# 14        Malminkaari 15, 00700 Helsinki, Finland
# 15            Kylätie 23, 00320 Helsinki, Finland
# 16  Malminkartanontie 17, 00410 Helsinki, Finland
# 17    Oulunkylän tori 2b, 00640 Helsinki, Finland
# 18        Ratapihantie 6, 00101 Helsinki, Finland
# 19     Pitäjänmäentie 15, 00370 Helsinki, Finland
# 20          Eskolantie 2, 00720 Helsinki, Finland
# 21      Tattariharjuntie, 00700 Helsinki, Finland
# 22      Tallinnanaukio 1, 00930 Helsinki, Finland
# 23      Tyynylaavantie 7, 00980 Helsinki, Finland
# 24       Myllypurontie 5, 00920 Helsinki, Finland
# 25    Mellunmäenraitio 6, 00970 Helsinki, Finland
# 26         Vaasanpolku 2, 00101 Helsinki, Finland
# 27        Hiihtäjäntie 2, 00810 Helsinki, Finland
# 28   Ukko-Pekan porras 2, 00570 Helsinki, Finland
# 29    Siltasaarenkatu 16, 00530 Helsinki, Finland
# 30  Urho Kekkosen katu 1, 00100 Helsinki, Finland
# 31    Ruoholahdenkatu 17, 00101 Helsinki, Finland
# 32     Tyynenmerenkatu 3, 00220 Helsinki, Finland
# 33          Vilhonkatu 4, 00101 Helsinki, Finland

# %%
type(geocoded_addresses_with_id)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
geocoded_addresses.head()
# Out:
#                     geometry  \
# 0  POINT (24.91556 60.16320)
# 1  POINT (24.93166 60.16905)
# 2  POINT (24.94179 60.16989)
# 3  POINT (24.97840 60.18934)
# 4  POINT (24.92169 60.15667)
#
#                                              address
# 0  Ruoholahti, 14, Itämerenkatu, Ruoholahti, Läns...
# 1  Kamppi, 1, Kampinkuja, Kamppi, Eteläinen suurp...
# 2  Kauppakeskus Citycenter, 8, Kaivokatu, Keskust...
# 3  Hermannin rantatie, Verkkosaari, Kalasatama, S...
# 4  9, Tyynenmerenkatu, Jätkäsaari, Länsisatama, E...

# %%
geocoded_addresses_with_id.to_file(DATA_DIRECTORY / "addresses.gpkg")
